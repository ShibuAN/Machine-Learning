# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#importing dataset by pandas
dataset=pd.read_csv(r"C:\Users\ShibuKumar\Downloads\Datas\Mall_Customers.csv")
dataset.head()
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
df=dataset.iloc[:,[3,4]]
df
# Out:
#      Annual Income (k$)  Spending Score (1-100)
# 0                    15                      39
# 1                    15                      81
# 2                    16                       6
# 3                    16                      77
# 4                    17                      40
# ..                  ...                     ...
# 195                 120                      79
# 196                 126                      28
# 197                 126                      74
# 198                 137                      18
# 199                 137                      83
#
# [200 rows x 2 columns]

# %%
plt.figure(figsize=(10,7))
plt.scatter(df[["Annual Income (k$)"]],df[["Spending Score (1-100)"]],s=100,c="blue")

# %%
import scipy.cluster.hierarchy as sch
plt.figure(figsize=(10,7))
dendrogram=sch.dendrogram(sch.linkage(df,method="ward"))
plt.title("Dendrogram")
plt.xlabel("Customers")
plt.ylabel("Euclidean Distances")
plt.show()

# %%
from sklearn.cluster import AgglomerativeClustering
Cluster=AgglomerativeClustering(n_clusters=2,metric=2,linkage="ward")
cl=cluster.fit_predict(df)

# %%
from sklearn.metrics import silhouette_score
silhouette_score(df,cl)
# Out:
# 0.4618340266628975

# %%
#The Slihouette score was low so we wil use to scaled data
from sklearn.preprocessing import normalize
scaled=normalize(x)
scaled = pd.DataFrame(scaled)
scaled.head()
# Out:
#           0         1
# 0  0.784883  0.619644
# 1  0.813733  0.581238
# 2  0.780869  0.624695
# 3  0.820905  0.571064
# 4  0.876812  0.480833

# %%
cl=cluster.fit_predict(scaled)

# %%
from sklearn.metrics import silhouette_score
silhouette_score(scaled,cl)
# Out:
# 0.6184099257331396
