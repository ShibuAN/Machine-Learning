# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv(r"C:\Users\ShibuKumar\Downloads\Datas\survey lung cancer.csv")
dataset.head()
# Out:
#   GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0      M   69        1               2        2              1
# 1      M   74        2               1        1              1
# 2      F   59        1               1        1              2
# 3      M   63        2               2        2              1
# 4      F   63        1               2        1              1
#
#    CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  COUGHING  \
# 0                1         2         1         2                  2         2
# 1                2         2         2         1                  1         1
# 2                1         2         1         2                  1         2
# 3                1         1         1         1                  2         1
# 4                1         1         1         2                  1         2
#
#    SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN LUNG_CANCER
# ...

# %%
dataset.shape
# Out:
# (309, 16)

# %%
dataset.size
# Out:
# 4944

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309 entries, 0 to 308
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   GENDER                 309 non-null    object
#  1   AGE                    309 non-null    int64
#  2   SMOKING                309 non-null    int64
#  3   YELLOW_FINGERS         309 non-null    int64
#  4   ANXIETY                309 non-null    int64
#  5   PEER_PRESSURE          309 non-null    int64
#  6   CHRONIC DISEASE        309 non-null    int64
#  7   FATIGUE                309 non-null    int64
#  8   ALLERGY                309 non-null    int64
#  9   WHEEZING               309 non-null    int64
#  10  ALCOHOL CONSUMING      309 non-null    int64
#  11  COUGHING               309 non-null    int64
#  12  SHORTNESS OF BREATH    309 non-null    int64
#  13  SWALLOWING DIFFICULTY  309 non-null    int64
#  14  CHEST PAIN             309 non-null    int64
# ...

# %%
dataset.count()
# Out:
# GENDER                   309
# AGE                      309
# SMOKING                  309
# YELLOW_FINGERS           309
# ANXIETY                  309
# PEER_PRESSURE            309
# CHRONIC DISEASE          309
# FATIGUE                  309
# ALLERGY                  309
# WHEEZING                 309
# ALCOHOL CONSUMING        309
# COUGHING                 309
# SHORTNESS OF BREATH      309
# SWALLOWING DIFFICULTY    309
# CHEST PAIN               309
# LUNG_CANCER              309
# dtype: int64

# %%
dataset.LUNG_CANCER.value_counts()
# Out:
# LUNG_CANCER
# YES    270
# NO      39
# Name: count, dtype: int64

# %%
malignent=dataset[dataset.LUNG_CANCER == "YES"][0:30]
benign=dataset[dataset.LUNG_CANCER == "NO"][0:30]

# %%
malignent.plot(kind="scatter",x="AGE",y="SMOKING",color="red",label="Malignent")
benign.plot(kind="scatter",x="AGE",y="SMOKING",color="blue",label="Benign")
# Out:
# <Axes: xlabel='AGE', ylabel='SMOKING'>

# %%
#how to compain 2graphs
malignent=malignent.plot(kind="scatter",x="AGE",y="SMOKING",color="red",label="Malignent")
benign.plot(kind="scatter",x="AGE",y="SMOKING",color="blue",label="Benign",ax=malignent)
# Out:
# <Axes: xlabel='AGE', ylabel='SMOKING'>

# %%
dataset.dtypes
# Out:
# GENDER                   object
# AGE                       int64
# SMOKING                   int64
# YELLOW_FINGERS            int64
# ANXIETY                   int64
# PEER_PRESSURE             int64
# CHRONIC DISEASE           int64
# FATIGUE                   int64
# ALLERGY                   int64
# WHEEZING                  int64
# ALCOHOL CONSUMING         int64
# COUGHING                  int64
# SHORTNESS OF BREATH       int64
# SWALLOWING DIFFICULTY     int64
# CHEST PAIN                int64
# LUNG_CANCER              object
# dtype: object

# %%
dataset.GENDER
# Out:
# 0      M
# 1      M
# 2      F
# 3      M
# 4      F
#       ..
# 304    F
# 305    M
# 306    M
# 307    M
# 308    M
# Name: GENDER, Length: 309, dtype: object

# %%
#we will see all itema
list(dataset.GENDER)
# Out:
# ['M',
#  'M',
#  'F',
#  'M',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'M',
#  'F',
#  'M',
#  'F',
#  'M',
#  'M',
#  'F',
#  'M',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'M',
#  'M',
#  'F',
#  'M',
#  'F',
#  'M',
#  'F',
#  'M',
#  'M',
#  'F',
#  'M',
#  'F',
#  'M',
#  'F',
#  'M',
#  'M',
#  'M',
#  'M',
#  'F',
#  'M',
#  'F',
#  'M',
#  'M',
#  'F',
#  'F',
#  'M',
#  'F',
#  'M',
#  'F',
#  'M',
#  'F',
#  'M',
#  'F',
#  'M',
#  'M',
#  'M',
#  'M',
#  'F',
#  'M',
#  'F',
#  'M',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'M',
#  'F',
#  'M',
#  'F',
#  'M',
#  'M',
#  'F',
#  'M',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'M',
#  'M',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'F',
#  'M',
#  'M',
#  'F',
#  'M',
#  'M',
#  'M',
#  'M',
#  'F',
#  'M',
#  'M',
#  'F',
#  'F',
#  'F',
#  'F',
#  'F',
#  'M',
#  'M',
#  'M',
#  'F',
#  'M',
#  'F',
#  'F',
#  'M',
#  'F',
#  'F',
#  'F',
#  'M',
#  'M',
#  'M',
#  'F',
#  'M',
# ...

# %%
dataset.isnull().sum()
dataset
# Out:
#     GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0        M   69        1               2        2              1
# 1        M   74        2               1        1              1
# 2        F   59        1               1        1              2
# 3        M   63        2               2        2              1
# 4        F   63        1               2        1              1
# ..     ...  ...      ...             ...      ...            ...
# 304      F   56        1               1        1              2
# 305      M   70        2               1        1              1
# 306      M   58        2               1        1              1
# 307      M   67        2               1        2              1
# 308      M   62        1               1        1              2
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 0                  1         2         1         2                  2
# ...

# %%
# #we will change the dataset to numeric
# dataset=dataset[pd.to_numeric(dataset.GENDER,errors="coerce").notnull()]
# dataset.GENDER=dataset.GENDER.astype("int")
# dataset

# %%
dataset.dtypes
# Out:
# GENDER                   object
# AGE                       int64
# SMOKING                   int64
# YELLOW_FINGERS            int64
# ANXIETY                   int64
# PEER_PRESSURE             int64
# CHRONIC DISEASE           int64
# FATIGUE                   int64
# ALLERGY                   int64
# WHEEZING                  int64
# ALCOHOL CONSUMING         int64
# COUGHING                  int64
# SHORTNESS OF BREATH       int64
# SWALLOWING DIFFICULTY     int64
# CHEST PAIN                int64
# LUNG_CANCER              object
# dtype: object

# %%
dataset.columns
# Out:
# Index(['GENDER', 'AGE', 'SMOKING', 'YELLOW_FINGERS', 'ANXIETY',
#        'PEER_PRESSURE', 'CHRONIC DISEASE', 'FATIGUE ', 'ALLERGY ', 'WHEEZING',
#        'ALCOHOL CONSUMING', 'COUGHING', 'SHORTNESS OF BREATH',
#        'SWALLOWING DIFFICULTY', 'CHEST PAIN', 'LUNG_CANCER'],
#       dtype='object')

# %%
# x_df=dataset[['AGE', 'SMOKING', 'YELLOW_FINGERS', 'ANXIETY',
#        'PEER_PRESSURE', 'CHRONIC DISEASE', 'FATIGUE ', 'ALLERGY ', 'WHEEZING',
#        'ALCOHOL CONSUMING', 'COUGHING', 'SHORTNESS OF BREATH',
#        'SWALLOWING DIFFICULTY', 'CHEST PAIN']]
x=np.asarray(dataset.iloc[:,1:15])
y=np.asarray(dataset.LUNG_CANCER)

# %%
x[0:5]
# Out:
# array([[69,  1,  2,  2,  1,  1,  2,  1,  2,  2,  2,  2,  2,  2],
#        [74,  2,  1,  1,  1,  2,  2,  2,  1,  1,  1,  2,  2,  2],
#        [59,  1,  1,  1,  2,  1,  2,  1,  2,  1,  2,  2,  1,  2],
#        [63,  2,  2,  2,  1,  1,  1,  1,  1,  2,  1,  1,  2,  2],
#        [63,  1,  2,  1,  1,  1,  1,  1,  2,  1,  2,  2,  1,  1]],
#       dtype=int64)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=0,test_size=0.3)

# %%
from sklearn import svm
svm_classifier = svm.SVC(kernel="linear",gamma="auto",C=2)

# %%
svm_classifier.fit(x_train,y_train)
# Out:
# SVC(C=2, gamma='auto', kernel='linear')

# %%
y_predict = svm_classifier.predict(x_test)
y_predict
# Out:
# array(['YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES',
#        'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'NO',
#        'YES', 'NO', 'YES', 'YES', 'YES', 'YES', 'NO', 'NO', 'YES', 'YES',
#        'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES',
#        'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'NO',
#        'YES', 'YES', 'YES', 'NO', 'YES', 'YES', 'YES', 'YES', 'YES',
#        'YES', 'YES', 'NO', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'NO',
#        'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES',
#        'NO', 'YES', 'YES', 'YES', 'YES', 'YES', 'NO', 'YES', 'YES', 'YES',
#        'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES', 'YES'],
#       dtype=object)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_predict))
# Out:
#               precision    recall  f1-score   support
#
#           NO       0.70      0.47      0.56        15
#          YES       0.90      0.96      0.93        78
#
#     accuracy                           0.88        93
#    macro avg       0.80      0.71      0.75        93
# weighted avg       0.87      0.88      0.87        93
